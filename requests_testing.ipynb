# %%
from requests_html import HTMLSession
session = HTMLSession()

# %%
r = session.get('https://en.wiktionary.org/wiki/koira')

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
span = soup.find(class_='form-of singular-ablative-form-of lang-fi')

# %%
link = span.find('a')

# %%
link['title']
# Out:
# 'omenalta'

# %%
noun_forms_dict = {
    "Plural Nominative": "form-of plural-nominative-form-of lang-fi",
    "Singular Partitive": "form-of singular-partitive-form-of lang-fi",
    "Plural Partitive": "form-of plural-partitive-form-of lang-fi",
    "Singular Genitive": "form-of singular-genitive-form-of lang-fi",
    "Plural Genitive": "form-of plural-genitive-form-of lang-fi",
    "Singular Illative": "form-of singular-illative-form-of lang-fi",
    "Plural Illative": "form-of plural-illative-form-of lang-fi",
    "Singular Inessive": "form-of singular-inessive-form-of lang-fi",
    "Plural Inessive": "form-of plural-inessive-form-of lang-fi",
    "Singular Elative": "form-of singular-elative-form-of lang-fi",
    "Plural Elative": "form-of plural-elative-form-of lang-fi",
    "Singular Adessive": "form-of singular-adessive-form-of lang-fi",
    "Plural Adessive": "form-of plural-adessive-form-of lang-fi",
    "Singular Ablative": "form-of singular-ablative-form-of lang-fi",
    "Plural Ablative": "form-of plural-ablative-form-of lang-fi",
    "Singular Allative": "form-of singular-allative-form-of lang-fi",
    "Plural Allative": "form-of plural-allative-form-of lang-fi",
    "Singular Essive": "form-of singular-essive-form-of lang-fi",
    "Plural Essive": "form-of plural-essive-form-of lang-fi",
    "Singular Translative": "form-of singular-translative-form-of lang-fi",
    "Plural Translative": "form-of plural-translative-form-of lang-fi",
    "Singular Abessive": "form-of singular-abessive-form-of lang-fi",
    "Plural Abessive": "form-of plural-abessive-form-of lang-fi"
}

# %%
for key, value in noun_forms_dict.items():
    span = soup.find(class_=value)
    link = span.find('a')
    form = link['title'].split(" ")[0]
    print("{}: {}".format(key, form))
# Out:
# Plural Nominative: koirat
# Singular Partitive: koiraa
# Plural Partitive: koiria
# Singular Genitive: koiran
# Plural Genitive: koirien
# Singular Illative: koiraan
# Plural Illative: koiriin
# Singular Inessive: koirassa
# Plural Inessive: koirissa
# Singular Elative: koirasta
# Plural Elative: koirista
# Singular Adessive: koiralla
# Plural Adessive: koirilla
# Singular Ablative: koiralta
# Plural Ablative: koirilta
# Singular Allative: koiralle
# Plural Allative: koirille
# Singular Essive: koirana
# Plural Essive: koirina
# Singular Translative: koiraksi
# Plural Translative: koiriksi
# Singular Abessive: koiratta
# Plural Abessive: koiritta

# %%
r = session.get('https://en.wiktionary.org/wiki/antaa')
soup = BeautifulSoup(r.text, 'html.parser')

# %%
spans=soup.find_all(lang='fi')

# %%
adding = False
verb_forms = []
for span in spans:
    # First valid entry will be first person singular which will always end in an 'n'
    if span.text[-1] == 'n':
        adding = True
    if adding:
        verb_forms.append(span.text)

# %%
verb_forms_list = [
    "First person",
    "First person negative",
    "First person perfect",
    "First person perfect negative",
    "Second person",
    "Second person negative",
    "Second person perfect",
    "Second person perfect negative",
    "Third person",
    "Third person negative",
    "Third person perfect",
    "Third person perfect negative",
    "First person plural",
    "First person plural negative",
    "First person plural perfect",
    "First person plural perfect negative",
    "Second person plural",
    "Second person plural negative",
    "Second person plural perfect",
    "Second person plural perfect negative",
    "Third person plural",
    "Third person plural negative",
    "Third person plural perfect",
    "Third person plural perfect negative",
    "Passive",
    "Passive negative",
    "Passive perfect",
    "Passive perfect negative",
    "First person past",
    "First person past negative",
    "First person pluperfect",
    "First person pluperfect negative",
    "Second person past",
    "Second person past negative",
    "Second person pluperfect",
    "Second person pluperfect negative",
    "Third person past",
    "Third person past negative",
    "Third person pluperfect",
    "Third person pluperfect negative",
    "First person past plural",
    "First person past plural negative",
    "First person pluperfect plural",
    "First person pluperfect plural negative",
    "Second person past plural",
    "Second person past plural negative",
    "Second person pluperfect plural",
    "Second person pluperfect plural negative",
    "Third person past plural",
    "Third person past plural negative",
    "Third person pluperfect plural",
    "Third person pluperfect plural negative",
    "Passive past",
    "Passive past negative",
    "Passive pluperfect",
    "Passive pluperfect negative",
    "First person conditional",
    "First person conditional negative",
    "First person conditional perfect",
    "First person conditional perfect negative",
    "Second person conditional",
    "Second person conditional negative",
    "Second person conditional perfect",
    "Second person conditional perfect negative",
    "Third person conditional",
    "Third person conditional negative",
    "Third person conditional perfect",
    "Third person conditional perfect negative",
    "First person conditional plural",
    "First person conditional plural negative",
    "First person conditional plural perfect",
    "First person conditional plural perfect negative",
    "Second person conditional plural",
    "Second person conditional plural negative",
    "Second person conditional plural perfect",
    "Second person conditional plural perfect negative",
    "Third person conditional plural",
    "Third person conditional plural negative",
    "Third person conditional plural perfect",
    "Third person conditional plural perfect negative",
    "Passive conditional",
    "Passive conditional negative",
    "Passive conditional perfect",
    "Passive conditional perfect negative",   
    "Second person imperative",
    "Second person imperative negative",
    "Second person imperative perfect",
    "Second person imperative perfect negative",
    "Third person imperative",
    "Third person imperative negative",
    "Third person imperative perfect",
    "Third person imperative perfect negative",
    "First person imperative plural",
    "First person imperative plural negative",
    "First person imperative plural perfect",
    "First person imperative plural perfect negative",
    "Second person imperative plural",
    "Second person imperative plural negative",
    "Second person imperative plural perfect",
    "Second person imperative plural perfect negative",
    "Third person imperative plural",
    "Third person imperative plural negative",
    "Third person imperative plural perfect",
    "Third person imperative plural perfect negative",
    "Passive imperative",
    "Passive imperative negative",
    "Passive imperative perfect",
    "Passive imperative perfect negative",
    "First person potential",
    "First person potential negative",
    "First person potential perfect",
    "First person potential perfect negative",
    "Second person potential",
    "Second person potential negative",
    "Second person potential perfect",
    "Second person potential perfect negative",
    "Third person potential",
    "Third person potential negative",
    "Third person potential perfect",
    "Third person potential perfect negative",
    "First person potential plural",
    "First person potential plural negative",
    "First person potential plural perfect",
    "First person potential plural perfect negative",
    "Second person potential plural",
    "Second person potential plural negative",
    "Second person potential plural perfect",
    "Second person potential plural perfect negative",
    "Third person potential plural",
    "Third person potential plural negative",
    "Third person potential plural perfect",
    "Third person potential plural perfect negative",
    "Passive potential",
    "Passive potential negative",
    "Passive potential perfect",
    "Passive potential perfect negative",
    "1st infinitive",
    "Present active participle",
    "Present passive participle",
    "A infinitive, long form",
    "Past active participle",
    "Past passive participle",
    "E infinitive inessive",
    "E infinitive inessive passive",
    "Agent participle",
    "E infinitive instructive",
    "Negative participle",
    "MA infinitive inessive",
    "MA infinitive elative",
    "MA infinitive illative",
    "MA infinitive adessive",
    "MA infinitive abessive",
    "MA infinitive instructive",
    "MA infinitive instructive passive",
    "MI infinitive nominative",
    "MI infinitive partitive",
    "5th infinitive"
]

# %% [markdown]
# You could turn the above into a dictionary with the values being the English equivalent forms (when available). Then the program could ask to translate the English verb phrase: "I have studied" rather than asking for the first person perfect

# %%
for form, verb in zip(verb_forms_list, verb_forms):
    print("{}: {}".format(form, verb))
# Out:
# First person: annan
# First person negative: en anna
# First person perfect: olen antanut
# First person perfect negative: en ole antanut
# Second person: annat
# Second person negative: et anna
# Second person perfect: olet antanut
# Second person perfect negative: et ole antanut
# Third person: antaa
# Third person negative: ei anna
# Third person perfect: on antanut
# Third person perfect negative: ei ole antanut
# First person plural: annamme
# First person plural negative: emme anna
# First person plural perfect: olemme antaneet
# First person plural perfect negative: emme ole antaneet
# Second person plural: annatte
# Second person plural negative: ette anna
# Second person plural perfect: olette antaneet
# Second person plural perfect negative: ette ole antaneet
# Third person plural: antavat
# Third person plural negative: eivät anna
# Third person plural perfect: ovat antaneet
# Third person plural perfect negative: eivät ole antaneet
# Passive: annetaan
# Passive negative: ei anneta
# Passive perfect: on annettu
# Passive perfect negative: ei ole annettu
# First person past: annoin
# First person past negative: en antanut
# First person pluperfect: olin antanut
# First person pluperfect negative: en ollut antanut
# Second person past: annoit
# Second person past negative: et antanut
# Second person pluperfect: olit antanut
# Second person pluperfect negative: et ollut antanut
# Third person past: antoi
# Third person past negative: ei antanut
# Third person pluperfect: oli antanut
# Third person pluperfect negative: ei ollut antanut
# First person past plural: annoimme
# First person past plural negative: emme antaneet
# First person pluperfect plural: olimme antaneet
# First person pluperfect plural negative: emme olleet antaneet
# Second person past plural: annoitte
# Second person past plural negative: ette antaneet
# Second person pluperfect plural: olitte antaneet
# Second person pluperfect plural negative: ette olleet antaneet
# Third person past plural: antoivat
# Third person past plural negative: eivät antaneet
# Third person pluperfect plural: olivat antaneet
# Third person pluperfect plural negative: eivät olleet antaneet
# Passive past: annettiin
# Passive past negative: ei annettu
# Passive pluperfect: oli annettu
# Passive pluperfect negative: ei ollut annettu
# First person conditional: antaisin
# First person conditional negative: en antaisi
# First person conditional perfect: olisin antanut
# First person conditional perfect negative: en olisi antanut
# Second person conditional: antaisit
# Second person conditional negative: et antaisi
# Second person conditional perfect: olisit antanut
# Second person conditional perfect negative: et olisi antanut
# Third person conditional: antaisi
# Third person conditional negative: ei antaisi
# Third person conditional perfect: olisi antanut
# Third person conditional perfect negative: ei olisi antanut
# First person conditional plural: antaisimme
# First person conditional plural negative: emme antaisi
# First person conditional plural perfect: olisimme antaneet
# First person conditional plural perfect negative: emme olisi antaneet
# Second person conditional plural: antaisitte
# Second person conditional plural negative: ette antaisi
# Second person conditional plural perfect: olisitte antaneet
# Second person conditional plural perfect negative: ette olisi antaneet
# Third person conditional plural: antaisivat
# Third person conditional plural negative: eivät antaisi
# Third person conditional plural perfect: olisivat antaneet
# Third person conditional plural perfect negative: eivät olisi antaneet
# Passive conditional: annettaisiin
# Passive conditional negative: ei annettaisi
# Passive conditional perfect: olisi annettu
# Passive conditional perfect negative: ei olisi annettu
# Second person imperative: anna
# Second person imperative negative: älä anna
# Second person imperative perfect: ole antanut
# Second person imperative perfect negative: älä ole antanut
# Third person imperative: antakoon
# Third person imperative negative: älköön antako
# Third person imperative perfect: olkoon antanut
# Third person imperative perfect negative: älköön olko antanut
# First person imperative plural: antakaamme
# First person imperative plural negative: älkäämme antako
# First person imperative plural perfect: olkaamme antaneet
# First person imperative plural perfect negative: älkäämme olko antaneet
# Second person imperative plural: antakaa
# Second person imperative plural negative: älkää antako
# Second person imperative plural perfect: olkaa antaneet
# Second person imperative plural perfect negative: älkää olko antaneet
# Third person imperative plural: antakoot
# Third person imperative plural negative: älkööt antako
# Third person imperative plural perfect: olkoot antaneet
# Third person imperative plural perfect negative: älkööt olko antaneet
# Passive imperative: annettakoon
# Passive imperative negative: älköön annettako
# Passive imperative perfect: olkoon annettu
# Passive imperative perfect negative: älköön olko annettu
# First person potential: antanen
# First person potential negative: en antane
# First person potential perfect: lienen antanut
# First person potential perfect negative: en liene antanut
# Second person potential: antanet
# Second person potential negative: et antane
# Second person potential perfect: lienet antanut
# Second person potential perfect negative: et liene antanut
# Third person potential: antanee
# Third person potential negative: ei antane
# Third person potential perfect: lienee antanut
# Third person potential perfect negative: ei liene antanut
# First person potential plural: antanemme
# First person potential plural negative: emme antane
# First person potential plural perfect: lienemme antaneet
# First person potential plural perfect negative: emme liene antaneet
# Second person potential plural: antanette
# Second person potential plural negative: ette antane
# Second person potential plural perfect: lienette antaneet
# Second person potential plural perfect negative: ette liene antaneet
# Third person potential plural: antanevat
# Third person potential plural negative: eivät antane
# Third person potential plural perfect: lienevät antaneet
# Third person potential plural perfect negative: eivät liene antaneet
# Passive potential: annettaneen
# Passive potential negative: ei annettane
# Passive potential perfect: lienee annettu
# Passive potential perfect negative: ei liene annettu
# 1st infinitive: antaa
# Present active participle: antava
# Present passive participle: annettava
# A infinitive, long form: antaakseen
# Past active participle: antanut
# Past passive participle: annettu
# E infinitive inessive: antaessa
# E infinitive inessive passive: annettaessa
# Agent participle: antama
# E infinitive instructive: antaen
# Negative participle: antamaton
# MA infinitive inessive: antamassa
# MA infinitive elative: antamasta
# MA infinitive illative: antamaan
# MA infinitive adessive: antamalla
# MA infinitive abessive: antamatta
# MA infinitive instructive: antaman
# MA infinitive instructive passive: annettaman
# MI infinitive nominative: antaminen
# MI infinitive partitive: antamista
# 5th infinitive: antamaisillaan

# %%
verb_forms
# Out:
# []
